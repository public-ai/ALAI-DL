# %% [markdown]
# ##  Linear Regression & Loss Function

# %%
# %matplotlib inline
import numpy as np

import matplotlib.pyplot as plt

# %% [markdown]
# ## 문제 1 Grid Search를 활용한 Linear Regression
#
# linear regression 과 **Grid Search**  을 이용해 아래 데이터를 linear regression 해주세요.

# %% [markdown]
# ###  Grid Search
#
#
# 1. 탐색할 가중치 조합을 구성합니다. 이 때 `np.meshgrid` 혹은 `np.mgrid`로 구성합니다.
#
# 2. 위의 가중치 조합에서 가중치를 뽑아, 예측값을 산출합니다.
#
# 3. 실제 값과 예측값의 차이를 MSE로 계산합니다.
#
# 3. 모든 가중치 조합 중 가장 작은 MSE를 보이는 Loss값 조합을 찾습니다.

# %%
# 아래 코드를 실행해 주세요 
num_points = 1000
vectors_set = []
for i in range(num_points):
    x1= np.random.normal(0.0, 0.55)
    y1= x1 * 0.1 + 0.3 + np.random.normal(0.0, 0.03)
    vectors_set.append([x1, y1])

xs = np.asarray([v[0] for v in vectors_set])
ys = np.asarray([v[1] for v in vectors_set])

plt.plot(xs, ys, 'ro', label='Original data')
plt.legend()
plt.show()

# %% [markdown]
# #### 답안지 입력란
# * 아래에 답을 서술하여 주세요

# %%
w0, w1 = np.meshgrid( np.arange(-10, 10, 0.1), np.arange(-10, 10, 0.1))
WS = np.stack(map(np.ravel, [w0, w1]), axis=-1)

losses = []
for W in WS:
    pred = xs * W[0] +W[1]
    losses.append(np.sum((pred - ys)**2))

best_W = WS[np.argmin(losses)]
best_pred = xs * best_W[0]+ best_W[1]
plt.scatter(xs, ys, alpha=0.1, label='true')
plt.scatter(xs , best_pred, alpha=0.5, label='pred')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# #### 정답 확인
# * 아래와 같이 출력이 나오도록 해주세요
#
# ![Imgur](https://i.imgur.com/zEiW7zM.png)

# %% [markdown]
# ## 문제 2
#
# 문제 1과 동일합니다. 다만 Loss function은 MAE(mean absolute Error)을 사용합니다 <br>
# 아래와 같은 그림이 나올수 있도록 Linear Regression 결과를 시각화 해주세요

# %%
# 아래 코드를 실행해 주세요 
num_points = 1000
vectors_set = []
for i in range(num_points):
    x1= np.random.normal(0.0, 0.55)
    y1= x1 * 0.1 + 0.3 + np.random.normal(0.0, 0.03)
    vectors_set.append([x1, y1])

xs = np.asarray([v[0] for v in vectors_set])
ys = np.asarray([v[1] for v in vectors_set])

plt.plot(xs, ys, 'ro', label='Original data')
plt.legend()
plt.show()

# %% [markdown]
# #### 답안지 입력란
# * 아래에 답을 서술하여 주세요

# %%
w0, w1 = np.meshgrid( np.arange(-10, 10, 0.1), np.arange(-10, 10, 0.1))
WS = np.stack(map(np.ravel, [w0, w1]), axis=-1)

losses = []
for W in WS:
    pred = xs * W[0] +W[1]
    losses.append(np.sum(np.abs(pred - ys)))

best_W = WS[np.argmin(losses)]
best_pred = xs * best_W[0]+ best_W[1]
plt.scatter(xs, ys, alpha=0.1, label='true')
plt.scatter(xs , best_pred, alpha=0.5, label='pred')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# #### 정답 확인
# * 아래와 같이 출력이 나오도록 해주세요
#
# ![Imgur](https://i.imgur.com/ycO3RGp.png)

# %% [markdown]
# #
#
# ---
#
#     Copyright(c) 2019 by Public AI. All rights reserved.<br>
#     Writen by PAI, SangJae Kang ( rocketgrowthsj@publicai.co.kr )  last updated on 2019/04/19
#
# ---
